# %%
Verificação da temperatura

# %%
temperatura = float(input("Temperatura atual: "))

temperatura_segura = X

if temperatura <= temperatura_segura:
    print("Temperatura OK")
else:
    print("DECOLAGEM ABORTADA")

# %%
Verificação da energia

# %%
energia = float(input("Energia atual (%): "))
energia_segura = X

if energia >= energia_segura:
    print("Energia OK")
else:
    print("DECOLAGEM ABORTADA")
